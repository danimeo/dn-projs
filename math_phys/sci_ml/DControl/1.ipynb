# %%
import control
import matplotlib.pyplot as plt
# %matplotlib inline

g = control.tf([1], [1, 2, 1])
print(g)
t, res = control.step_response(g)
plt.plot(t, res)
plt.show()

g2 = control.tf([4, 68, 412, 1068, 1152, 432], [1, 6, 12, 15, 18, 15, 5, 0])
print(g2)
t, res = control.step_response(g2)
plt.plot(t, res)
plt.show()
# Out:
#       1
# -------------
# s^2 + 2 s + 1
#  4 s^5 + 68 s^4 + 412 s^3 + 1068 s^2 + 1152 s + 432
# -----------------------------------------------------
# s^7 + 6 s^6 + 12 s^5 + 15 s^4 + 18 s^3 + 15 s^2 + 5 s

# %%
import control
sys = control.tf([11], [1, 5, 7, 9, 11])
control.pzmap(sys)
# Out:
# (array([-3.46499359+0.j        , -1.66806693+0.j        ,
#          0.06653026+1.37794782j,  0.06653026-1.37794782j]),
#  array([], dtype=float64))
